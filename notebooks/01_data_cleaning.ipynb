# %% [markdown]
# # **01: Data Cleaning & ETL**

# %% [markdown]
# This first notebook contains the full exploratory analysis and cleaning of the *online_retail_II* dataset.

# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine

# %% [markdown]
# # Table of Contents

# %% [markdown]
# 1. [Extract](#11-extract)
# 2. [Data Quality Assessment](#12-data-quality-assessment)
#    - [Null or Missing Values](#121-null-or-missing-values)
#    - [Non-transactional Records](#122-non-transactional-records)
# 3. [Transform](#13-transform)
#    - [Removing negative Prices and Missing Descriptions](#131-removing-negative-price-and-missing-description)
#    - [Removing zero Prices and Missing Customer ID](#132-removing-zero-price-and-missing-customer-id)
#    - [Removing Non-transactional Records](#133-removing-non-transactional-records)
#    - [Removing Duplicates](#134-removing-duplicates)
#    - [Type Conversion](#135-type-conversion)
#    - [Sales/Returns Separation](#136-salesreturns-separation)
# 4. [Validate](#14-validate)
# 5. [Load](#15-load)
# 6. [Summary](#16-summary)

# %% [markdown]
# ## 1.1 Extract

# %%
df = pd.read_csv("../data/online_retail_II.csv")

# %%
original_len = len(df)
df.shape
# Out:
# (1067371, 8)

# %% [markdown]
# ## 1.2 Data quality assessment

# %% [markdown]
# ### 1.2.1 Null or missing values

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df[df["Description"].isnull()].head()
# Out:
#      Invoice StockCode Description  Quantity          InvoiceDate  Price  \
# 470   489521     21646         NaN       -50  2009-12-01 11:44:00    0.0
# 3114  489655     20683         NaN       -44  2009-12-01 17:26:00    0.0
# 3161  489659     21350         NaN       230  2009-12-01 17:39:00    0.0
# 3731  489781     84292         NaN        17  2009-12-02 11:45:00    0.0
# 4296  489806     18010         NaN      -770  2009-12-02 12:42:00    0.0
#
#       Customer ID         Country
# 470           NaN  United Kingdom
# 3114          NaN  United Kingdom
# 3161          NaN  United Kingdom
# 3731          NaN  United Kingdom
# 4296          NaN  United Kingdom

# %%
df[df["Customer ID"].isnull()].head()
# Out:
#     Invoice StockCode                Description  Quantity  \
# 263  489464     21733               85123a mixed       -96
# 283  489463     71477                      short      -240
# 284  489467    85123A                21733 mixed      -192
# 470  489521     21646                        NaN       -50
# 577  489525    85226C  BLUE PULL BACK RACING CAR         1
#
#              InvoiceDate  Price  Customer ID         Country
# 263  2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 283  2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 284  2009-12-01 10:53:00   0.00          NaN  United Kingdom
# 470  2009-12-01 11:44:00   0.00          NaN  United Kingdom
# 577  2009-12-01 11:49:00   0.55          NaN  United Kingdom

# %%
null_desc = len(df[df["Description"].isnull()])
null_id = len(df[df["Customer ID"].isnull()])
zero_price = len(df[df["Price"]==0])
neg_price = len(df[df["Price"]<0])
print(f"{null_desc} rows with null Description;\n{null_id} rows with null Customer ID;\n{zero_price} rows with Price=0.00;\n{neg_price} rows with negative Price.")
# Out:
# 4382 rows with null Description;
# 243007 rows with null Customer ID;
# 6202 rows with Price=0.00;
# 5 rows with negative Price.

# %%
# Inspect correlation between zero-price and missing values
all_conditions = len(df[(df["Customer ID"].isnull()) & (df["Description"].isnull()) & (df["Price"] == 0)])
with_description = len(df[(df["Price"]==0) & (df["Customer ID"].isnull())]) - all_conditions
just_zero_price = len(df[(df["Price"]==0) & (df["Description"].notnull()) & (df["Customer ID"].notnull())])

# %%
print(f"Of ZERO-PRICED rows:\n{all_conditions} have both Description and Customer ID missng;")
print(f"{with_description} are missing just the Customer ID;")
print(f"{just_zero_price} have both Description and Customer ID.")
# Out:
# Of ZERO-PRICED rows:
# 4382 have both Description and Customer ID missng;
# 1749 are missing just the Customer ID;
# 71 have both Description and Customer ID.

# %%
# Zero-priced and no Customer ID
df[(df["Price"]==0) & (df["Customer ID"].isnull()) & (df["Description"].notnull())].head(5)
# Out:
#      Invoice StockCode   Description  Quantity          InvoiceDate  Price  \
# 263   489464     21733  85123a mixed       -96  2009-12-01 10:52:00    0.0
# 283   489463     71477         short      -240  2009-12-01 10:52:00    0.0
# 284   489467    85123A   21733 mixed      -192  2009-12-01 10:53:00    0.0
# 3162  489660     35956          lost     -1043  2009-12-01 17:43:00    0.0
# 3168  489663    35605A       damages      -117  2009-12-01 18:02:00    0.0
#
#       Customer ID         Country
# 263           NaN  United Kingdom
# 283           NaN  United Kingdom
# 284           NaN  United Kingdom
# 3162          NaN  United Kingdom
# 3168          NaN  United Kingdom

# %%
# Just zero-priced
df[(df["Price"]==0) & (df["Description"].notnull()) & (df["Customer ID"].notnull())].head(10)
# Out:
#       Invoice StockCode                      Description  Quantity  \
# 4674   489825     22076               6 RIBBONS EMPIRE          12
# 6781   489998     48185              DOOR MAT FAIRY CAKE         2
# 16107  490727         M                           Manual         1
# 18738  490961     22065   CHRISTMAS PUDDING TRINKET POT          1
# 18739  490961     22142     CHRISTMAS CRAFT WHITE FAIRY         12
# 32916  492079     85042        ANTIQUE LILY FAIRY LIGHTS         8
# 40101  492760     21143  ANTIQUE GLASS HEART DECORATION         12
# 47126  493761     79320                  FLAMINGO LIGHTS        24
# 48342  493899     22355      CHARLOTTE BAG , SUKI DESIGN        10
# 57619  494607     21533        RETRO SPOT LARGE MILK JUG        12
#
#                InvoiceDate  Price  Customer ID         Country
# 4674   2009-12-02 13:34:00    0.0      16126.0  United Kingdom
# 6781   2009-12-03 11:19:00    0.0      15658.0  United Kingdom
# 16107  2009-12-07 16:38:00    0.0      17231.0  United Kingdom
# 18738  2009-12-08 15:25:00    0.0      14108.0  United Kingdom
# 18739  2009-12-08 15:25:00    0.0      14108.0  United Kingdom
# 32916  2009-12-15 13:49:00    0.0      15070.0  United Kingdom
# 40101  2009-12-18 14:22:00    0.0      18071.0  United Kingdom
# 47126  2010-01-06 14:54:00    0.0      14258.0  United Kingdom
# 48342  2010-01-08 10:43:00    0.0      12417.0         Belgium
# 57619  2010-01-15 12:43:00    0.0      16858.0  United Kingdom

# %%
# Just Customer ID Missing
df[(df["Customer ID"].isnull()) & (df["Description"].notnull()) & (df["Price"]>0)].head(10)
# Out:
#      Invoice StockCode                       Description  Quantity  \
# 577   489525    85226C         BLUE PULL BACK RACING CAR         1
# 578   489525     85227       SET/6 3D KIT CARDS FOR KIDS         1
# 1055  489548     22271              FELTCRAFT DOLL ROSIE         1
# 1056  489548     22254              FELT TOADSTOOL LARGE        12
# 1057  489548     22273              FELTCRAFT DOLL MOLLY         3
# 1058  489548     22195      LARGE HEART MEASURING SPOONS         1
# 1059  489548     22131  FOOD CONTAINER SET 3 LOVE HEART          2
# 1060  489548     22079        RIBBON REEL HEARTS DESIGN         10
# 1061  489548     22138     BAKING SET 9 PIECE RETROSPOT          3
# 1062  489548     22147        FELTCRAFT BUTTERFLY HEARTS         2
#
#               InvoiceDate  Price  Customer ID         Country
# 577   2009-12-01 11:49:00   0.55          NaN  United Kingdom
# 578   2009-12-01 11:49:00   0.85          NaN  United Kingdom
# 1055  2009-12-01 12:32:00   2.95          NaN  United Kingdom
# 1056  2009-12-01 12:32:00   1.25          NaN  United Kingdom
# 1057  2009-12-01 12:32:00   2.95          NaN  United Kingdom
# 1058  2009-12-01 12:32:00   1.65          NaN  United Kingdom
# 1059  2009-12-01 12:32:00   1.95          NaN  United Kingdom
# 1060  2009-12-01 12:32:00   1.65          NaN  United Kingdom
# 1061  2009-12-01 12:32:00   4.95          NaN  United Kingdom
# 1062  2009-12-01 12:32:00   1.45          NaN  United Kingdom

# %%
# Negative price
df[df["Price"]<0]
# Out:
#         Invoice StockCode      Description  Quantity          InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1  2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1  2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1  2010-10-20 12:04:00
# 825444  A563186         B  Adjust bad debt         1  2011-08-12 14:51:00
# 825445  A563187         B  Adjust bad debt         1  2011-08-12 14:52:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom
# 825444 -11062.06          NaN  United Kingdom
# 825445 -11062.06          NaN  United Kingdom

# %% [markdown]
# Upon first inspection we notice a few things:
#
# 1. All rows with missing *Description*, also have null *Customer ID* and zero *Price*: these $4382$ rows may be removed, since too much info is missing for a relevant
# analysis.
#
# 2. $1749$ rows with missing *Customer ID* also have zero price. Upon inspection, it appears that most of these rows refer to damaged or lost products, and even those who have valid Description are already missing too much info (Customer ID and price) so I chose to remove them altogether from further analysis.
#
# 3. The rows in which ONLY *Customer ID* is null are $236876$; they may be kept since they retain meaningful information for statistical analysis on sales. They can be kept out of the analysis if later on we decide to focus on a customer-based analysis.
#
# 4. The rows in which all info is present but the *Price* is set to $0$ are $71$. Of these rows, some have descriptions that point to noise like "Manual" or "test". These may be removed.
#
# 5. $5$ rows have negative price, and they all have the same description: "Adjust bad debt". These can be safely removed as they correspond to accounting adjustments and do not represent actual transactions.

# %% [markdown]
# ### 1.2.2 Non-transactional records

# %% [markdown]
# Inspecting rows that only have zero price, we noticed that some rows were to be considered invalid based on their Description (eg. "test¨, "manual",...) or the Stock Code that was differently formatted.
# This is valid not only for zero-priced rows but the whole dataset, so in this section we focus on removing invalid samples from the whole remaining dataset.
#
#
# Manually removing rows with specific Descripions may be too unconvenient to implement, since "Manual" and "Test" are just some examples of invalid Descriptions and we cannot afford to look at all of them.
# Most valid samples have all uppergase Description, but I preferred to not use this criterium since it may be too strict (removed all rows where a unit of measurement like grams or cm is present in the description).
#
#
# The Stock Code may be more indicative.

# %%
# Before inspecting Stock Codes and Descriptions, let us clean them up by removing useless blank spaces
df["StockCode"]=df["StockCode"].str.strip()
df["Description"]=df["Description"].str.strip()

# %% [markdown]
# ##### 1. Non-alphanumeric Stock codes

# %%
# Are there non alphanumeric stock codes for valid data samples?
mask = (df["StockCode"].str.isalnum())
print("Unique entries with non alphanumeric Stock Code:")
print(df[~mask][["StockCode", "Description"]].drop_duplicates().sort_values("StockCode"))
# Out:
# Unique entries with non alphanumeric Stock Code:
#            StockCode                         Description
# 18410   BANK CHARGES                        Bank Charges
# 298848  gift_0001_10                                 NaN
# 40904   gift_0001_10  Dotcomgiftshop Gift Voucher £10.00
# 254427  gift_0001_20                                 NaN
# 754275  gift_0001_20  to push order througha s stock was
# 32048   gift_0001_20  Dotcomgiftshop Gift Voucher £20.00
# 45212   gift_0001_30  Dotcomgiftshop Gift Voucher £30.00
# 54564   gift_0001_30                                 NaN
# 299652  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00
# 75137   gift_0001_40                                 NaN
# 41263   gift_0001_50  Dotcomgiftshop Gift Voucher £50.00
# 75136   gift_0001_50                                 NaN
# 75138   gift_0001_60                                 NaN
# 75139   gift_0001_70                                 NaN
# 235291  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00
# 31079   gift_0001_80  Dotcomgiftshop Gift Voucher £80.00
# 30620   gift_0001_80                                 NaN
# 75141   gift_0001_90                                 NaN

# %% [markdown]
# All non-alphanumeric Stock Codes are not products. Bank charges can be safely removed as they correspond to external charges, while Gift vouchers lie in in a "grey area".
# They are real transactions with revenue, but are not specific products.
# **For the scope of this analysis** (which will focus on product-based revenue) they will be removed, even though they would have been relevant for a total revenue analysis.

# %% [markdown]
# ##### 2. Stock codes' lengths

# %%
# How are lengths distributed?
df["StockCode"].str.len().value_counts().sort_index()
# Out:
# StockCode
# 1       1713
# 2        283
# 3       1446
# 4       2158
# 5     932385
# 6     127591
# 7       1392
# 8        127
# 9         74
# 12       202
# Name: count, dtype: int64

# %%
# Explore less common stock code lengths
for i in [1,2,3,4,7,8,9]:
    print(f"\nUnique Objects with StockCode of length {i}:")
    print(df[df["StockCode"].str.len() == i][["StockCode", "Description"]].drop_duplicates().sort_values("StockCode"))
# Out:
# Unique Objects with StockCode of length 1:
#        StockCode      Description
# 179403         B  Adjust bad debt
# 735            D         Discount
# 2697           M           Manual
# 114061         S          SAMPLES
# 96608          m           Manual
#
# Unique Objects with StockCode of length 2:
#        StockCode Description
# 9292          C2    CARRIAGE
# 32207         C2         NaN
# 302041        C3         NaN
#
# Unique Objects with StockCode of length 3:
#        StockCode     Description
# 2379         DOT  DOTCOM POSTAGE
# 271469       DOT             NaN
#
# Unique Objects with StockCode of length 4:
#        StockCode                 Description
# 842969      CRUK             CRUK Commission
# 83304       GIFT                         NaN
# 62299       PADS  PADS TO MATCH ALL CUSHIONS
# 89          POST                     POSTAGE
# 191175      POST                         NaN
#
# Unique Objects with StockCode of length 7:
#        StockCode                         Description
# 613      15056BL             EDWARDIAN PARASOL BLACK
# 100348   15056BL                                 NaN
# 2620     15056bl             EDWARDIAN PARASOL BLACK
# 68648    72024HC                                 NaN
# 1762     79323GR                 GREEN CHERRY LIGHTS
# 6556     79323GR                        sold as gold
# 173046   79323GR                                 NaN
# 956840   79323GR              Unsaleable, destroyed.
# 572      79323LP            LIGHT PINK CHERRY LIGHTS
# 173045   79323LP                                 NaN
# 956838   79323LP              Unsaleable, destroyed.
# 249672   ADJUST2  Adjustment by Peter on Jun 25 2010
# 27994    TEST001             This is a test product.
# 39411    TEST002             This is a test product.
# 44614    TEST002                                 NaN
#
# Unique Objects with StockCode of length 8:
#        StockCode                       Description
# 804719  DCGS0003                              ebay
# 20249   DCGS0003               BOXED GLASS ASHTRAY
# 98951   DCGS0004                               NaN
# 8371    DCGS0004        HAYNES CAMPER SHOULDER BAG
# 80337   DCGS0006                               NaN
# 80338   DCGS0016                               NaN
# 80339   DCGS0027                               NaN
# 80342   DCGS0036                               NaN
# 236545  DCGS0037                KEY-RING CORKSCREW
# 98953   DCGS0037                               NaN
# 80361   DCGS0039                               NaN
# 222345  DCGS0041  HAYNES MINI-COOPER PLAYING CARDS
# 33819   DCGS0044           HANDZ-OFF CAR FRESHENER
# 98950   DCGS0053                               NaN
# 600298  DCGS0055                               NaN
# 81143   DCGS0056                               NaN
# 600756  DCGS0057                               NaN
# 413034  DCGS0058                               NaN
# 2377    DCGS0058                  MISO PRETTY  GUM
# 82846   DCGS0059                               NaN
# 80953   DCGS0060                               NaN
# 414064  DCGS0062           ROAD-RAGE CAR FRESHENER
# 98952   DCGS0062                               NaN
# 804718  DCGS0067                              ebay
# 2378    DCGS0068                 DOGS NIGHT COLLAR
# 804717  DCGS0068                              ebay
# 804716  DCGS0069                              ebay
# 123592  DCGS0069             OOH LA LA DOGS COLLAR
# 148842  DCGS0070             CAMOUFLAGE DOG COLLAR
# 804714  DCGS0070                               NaN
# 804713  DCGS0071                               NaN
# 30672   DCGS0072            CAT CAMOUFLAGUE COLLAR
# 600299  DCGS0072                               NaN
# 804712  DCGS0073                              ebay
# 600300  DCGS0074                               NaN
# 148843  DCGS0075              CAMOUFLAGUE DOG LEAD
# 8373    DCGS0076      SUNJAR LED NIGHT NIGHT LIGHT
# 89000   DCGSLBOY                               NaN
# 241371  DCGSSBOY                            update
# 244830  DCGSSBOY                    BOYS PARTY BAG
# 101692  DCGSSBOY                               NaN
#
# Unique Objects with StockCode of length 9:
#         StockCode              Description
# 440688  AMAZONFEE               AMAZON FEE
# 44245   DCGS0066N  NAVY CUDDLES DOG HOODIE
# 44335   DCGS0066N                      NaN
# 804715  DCGS0066P                      NaN
# 101693  DCGSLGIRL                      NaN
# 80231   DCGSSGIRL                      NaN
# 241372  DCGSSGIRL                   update
# 244831  DCGSSGIRL          GIRLS PARTY BAG

# %% [markdown]
# The great majority of samples has a stock code of length 5-6.
# Of the entries with different StockCode lengths:
#
# **Lenghts that can be removed**:
# Entries with Stock Codes of length 1-3, as they refer either to adjustments or delivery fees and do not serve the purpose of a sales analysis.
#
#
# **Specific Stock Codes that can be removed**:
# For Stock Codes with lenght >= 4, all entries with codes in:\["POST", "CRUK","ADJUST2", "TEST001", "TEST002", "AMAZONFEE"\]  can be safely removed.
# These all refer either to manual adjustments or external fees for deliveries or other types of charges: neither are products and therefore are irrelevant for a sales-based analysis.
# >NOTE: the additional code ADJUST was later found out during successive analysis. It bypassed these preliminary checks as its length is 6 (most common length) and Stock codes of length 6 were not manually checked one by one.

# %% [markdown]
# ## 1.3 Transform

# %% [markdown]
# ### 1.3.1 Removing negative Prices and missing Descriptions

# %% [markdown]
# We remove all rows that have negative Price (5) and all rows that have null Description.

# %%
# Remove negative price rows
clean_df = df[df["Price"]>=0]

# Remove rows with missing Description (also missing Customer ID and having zero-price)
clean_df = clean_df[clean_df["Description"].notnull()]

print(f"Number of data samples expected: {original_len-null_desc-neg_price}\nNumber of data samples: {len(clean_df)}")
# Out:
# Number of data samples expected: 1062984
# Number of data samples: 1062984

# %% [markdown]
# ### 1.3.2 Removing zero Prices & missing Customer ID

# %% [markdown]
# We remove, among rows with null Customer ID, the ones with zero Price, as they don't retain enough information.

# %%
prev_len = len(clean_df) # for checking

# Removing rows with zero price and missing Customer ID
mask = (clean_df["Price"]==0) & (clean_df["Customer ID"].isnull())
clean_df = clean_df[~mask]

print(f"Number of data samples expected: {prev_len-with_description}\nNumber of data samples: {(len(clean_df))}")
# Out:
# Number of data samples expected: 1061235
# Number of data samples: 1061235

# %% [markdown]
# ### 1.3.3 Removing non-transactional records

# %%
# Removing non-alphanumeric Stock Codes
clean_df = clean_df[clean_df["StockCode"].str.isalnum()]

# %%
# Removing all entries with len(StockCode)<4
clean_df = clean_df[clean_df["StockCode"].str.len()>=4]

# Removing all entries with specific codes
non_prod = ["POST", "CRUK","ADJUST","ADJUST2", "TEST001", "TEST002", "AMAZONFEE"]
mask = clean_df["StockCode"].isin(non_prod)
clean_df = clean_df[~mask]

# %% [markdown]
# ### 1.3.4 Removing duplicates
# Let us now make sure that there are no duplicates in the entries

# %%
print(clean_df.duplicated().sum())
clean_df[clean_df.duplicated(keep=False)].sort_values(by=["Invoice", "StockCode"]).head(10)
# Out:
# 34036
#     Invoice StockCode                      Description  Quantity  \
# 379  489517     21491  SET OF THREE VINTAGE GIFT WRAPS         1
# 391  489517     21491  SET OF THREE VINTAGE GIFT WRAPS         1
# 365  489517     21821  GLITTER STAR GARLAND WITH BELLS         1
# 386  489517     21821  GLITTER STAR GARLAND WITH BELLS         1
# 363  489517     21912         VINTAGE SNAKES & LADDERS         1
# 371  489517     21912         VINTAGE SNAKES & LADDERS         1
# 394  489517     21912         VINTAGE SNAKES & LADDERS         1
# 362  489517     21913   VINTAGE SEASIDE JIGSAW PUZZLES         1
# 385  489517     21913   VINTAGE SEASIDE JIGSAW PUZZLES         1
# 368  489517     22130  PARTY CONE CHRISTMAS DECORATION         6
#
#              InvoiceDate  Price  Customer ID         Country
# 379  2009-12-01 11:34:00   1.95      16329.0  United Kingdom
# 391  2009-12-01 11:34:00   1.95      16329.0  United Kingdom
# 365  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 386  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 363  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 371  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 394  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 362  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 385  2009-12-01 11:34:00   3.75      16329.0  United Kingdom
# 368  2009-12-01 11:34:00   0.85      16329.0  United Kingdom

# %%
clean_df = clean_df.drop_duplicates()

# %% [markdown]
# ### 1.3.5 Type conversion
# It's now best to make sure that InvoiceDates are in the datetime format, and that Customer ID is a string for clarity

# %%
clean_df.dtypes
# Out:
# Invoice            str
# StockCode          str
# Description        str
# Quantity         int64
# InvoiceDate        str
# Price          float64
# Customer ID    float64
# Country            str
# dtype: object

# %%
clean_df["InvoiceDate"] = pd.to_datetime(clean_df["InvoiceDate"])
clean_df["Customer ID"] = clean_df["Customer ID"].astype("str")
clean_df.dtypes
# Out:
# Invoice                   str
# StockCode                 str
# Description               str
# Quantity                int64
# InvoiceDate    datetime64[us]
# Price                 float64
# Customer ID               str
# Country                   str
# dtype: object

# %% [markdown]
# ### 1.3.6 Sales/returns separation

# %% [markdown]
# Returns are stored as entries with negative quantity. It may be useful to additionally create separate dataframes for sales and returns for clarity.

# %%
df_sales = clean_df[clean_df["Quantity"]>0].copy()
df_returns = clean_df[clean_df["Quantity"]<0].copy()

# %% [markdown]
# ## 1.4 Validate

# %%
assert clean_df["Description"].notna().all()
assert clean_df.duplicated().sum() == 0

# %% [markdown]
# ## 1.5 Load

# %%
# Load as csv
df_sales.to_csv("../data/sales_clean.csv", index=False)
df_returns.to_csv("../data/returns_clean.csv", index=False)

# %%
# create SQLite database
engine = create_engine("sqlite:///../data/retail.db")

# Load to SQLite database
df_sales.to_sql('sales', engine, if_exists='replace', index=False)
df_returns.to_sql('returns', engine, if_exists='replace', index=False)
# Out:
# 17915

# %% [markdown]
# ## 1.6 Summary

# %%
remov = original_len-len(clean_df)

print(f"Original dataset: {original_len} rows")
print(f"After cleaning: {len(clean_df)} rows")
print(f"Sales records: {len(df_sales)}")
print(f"Return records: {len(df_returns)}")
print(f"Removed: {remov} rows ({(remov/original_len)*100:.4f}% of original)")
# Out:
# Original dataset: 1067371 rows
# After cleaning: 1021333 rows
# Sales records: 1003418
# Return records: 17915
# Removed: 46038 rows (4.3132% of original)
